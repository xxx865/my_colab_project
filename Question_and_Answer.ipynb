# %% [markdown]
# <a href="https://colab.research.google.com/github/xxx865/my_colab_project/blob/main/Question_and_Answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-classic langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 kB 29.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.6.1
#     Uninstalling langchain-core-1.6.1:
#       Successfully uninstalled langchain-core-1.6.1
# ...

# %%
# !pip install -U langchain-classic langchain-deepseek

# %%
# !pip install -U langchain-classic langchain-deepseek

# %%
from google.colab import userdata
from langchain_classic.chains.sequential import SimpleSequentialChain
from langchain_classic.chains.llm import LLMChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_deepseek import ChatDeepSeek

api_key = userdata.get("DEEPSEEK_API_KEY")

llm = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0.0,
    api_key=api_key,
)

# %%
# %pip install -U langchain-classic langchain-community langchain-openai docarray
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
# %pip install -q requests==2.34.2

# %%
from langchain_community.document_loaders import CSVLoader
from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_classic.chains import RetrievalQA
# Out:
# /tmp/ipykernel_4902/1471224607.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import CSVLoader

# %%
from langchain_community.embeddings.openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
# Out:
# /tmp/ipykernel_4902/2008307582.py:2: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-openai package and should be used instead. To use it run `pip install -U `langchain-openai` and import as `from `langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipykernel_4902/2008307582.py in <cell line: 0>()
#       1 from langchain_community.embeddings.openai import OpenAIEmbeddings
# ----> 2 embeddings = OpenAIEmbeddings(model='text-embedding-3-small')
#
# /usr/local/lib/python3.13/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
# ...

# %%
# %pip install -qU langchain-huggingface sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.8/739.8 kB 11.5 MB/s eta 0:00:00

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-zh-v1.5"
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/27.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 95.8MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/71 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/439k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# ...

# %%
#因为文档比较短了，所以这里不需要进行任何分块,可以直接进行向量表征
#使用初始化OpenAIEmbedding实例上的查询方法embed_query为文本创建向量表征
embed = embeddings.embed_query("Hi my name is Harrison")

#查看得到向量表征的长度
print(len(embed))
# Out:
# 512

# %%
#每个元素都是不同的数字值，组合起来就是文本的向量表征
print(embed[:5])
# Out:
# [0.015478959307074547, 0.03694892302155495, 0.018284758552908897, -0.013923418708145618, -0.02915128320455551]

# %%
# 将刚才创建文本向量表征(embeddings)存储在向量存储(vector store)中
# 使用DocArrayInMemorySearch类的from_documents方法来实现
# 该方法接受文档列表以及向量表征模型作为输入
db = DocArrayInMemorySearch.from_documents(docs, embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2623/4253169502.py in <cell line: 0>()
#       2 # 使用DocArrayInMemorySearch类的from_documents方法来实现
#       3 # 该方法接受文档列表以及向量表征模型作为输入
# ----> 4 db = DocArrayInMemorySearch.from_documents(docs, embeddings)
#
# NameError: name 'DocArrayInMemorySearch' is not defined

# %%
# %pip install -qU langchain-community docarray
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 26.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
from langchain_community.vectorstores import DocArrayInMemorySearch
# Out:
# /tmp/ipykernel_2623/4098958416.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import DocArrayInMemorySearch

# %%
# %pip install -qU faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 74.6 MB/s eta 0:00:00

# %%
from langchain_core.documents import Document

documents = [
    Document(page_content="这是一段测试文本。"),
    Document(page_content="这是另一段测试文本。"),
]

vectorstore = FAISS.from_documents(
    documents,
    embeddings,
)

# %%
import langchain
langchain.__version__
# Out:
# '1.3.18'

# %%
query="Please suggest a shirt with sunblocking"
docs=vectorstore.similarity_search(query)
len(docs)
# Out:
# 2

# %%
# %pip install -U langchain-classic langchain-deepseek
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 kB 14.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.6.1
#     Uninstalling langchain-core-1.6.1:
#       Successfully uninstalled langchain-core-1.6.1
# ...

# %%
# %pip install -qU langchain-deepseek langchain-huggingface sentence-transformers langchain-community faiss-cpu

# %%
from google.colab import userdata
from langchain_deepseek import ChatDeepSeek
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document

api_key = userdata.get("DEEPSEEK_API_KEY")

documents = [
    Document(page_content="This shirt provides UV protection and blocks sunlight."),
    Document(page_content="This jacket is waterproof and suitable for rainy weather."),
]

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-en-v1.5"
)

vectorstore = FAISS.from_documents(
    documents,
    embeddings,
)

retriever = vectorstore.as_retriever()
# Out:
# /tmp/ipykernel_11561/290921023.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  133MB
# model.safetensors: downloading bytes:           |  0.00B
# ...

# %%
llm = ChatDeepSeek(
    model="deepseek-chat",
    temperature=0.0,
    api_key=api_key,
)

# %%
docs = retriever.invoke(
    "Please suggest a shirt with sunblocking"
)

for doc in docs:
    print(doc.page_content)
# Out:
# This shirt provides UV protection and blocks sunlight.
# This jacket is waterproof and suitable for rainy weather.

# %%
qdocs ="".join([docs[i].page_content for i in range(len(docs))])

# %%
context = "\n\n".join(
    doc.page_content for doc in qdocs
)
prompt = f"""请根据以下商品信息，列出所有具有防晒功能的衬衫。
请用 Markdown 表格展示，并简要总结每件衬衫。
商品信息：{context}"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11561/2440619647.py in <cell line: 0>()
# ----> 1 response = llm.call_as_llm(f"{qdocs} Question:Please list all your shirts with sun protection in a table in markdown and summarize each one.")
#
# /usr/local/lib/python3.13/dist-packages/pydantic/main.py in __getattr__(self, item)
#    1040                     else:
#    1041                         # this is the current error
# -> 1042                         raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#    1043
#    1044         def __setattr__(self, name: str, value: Any) -> None:
#
# AttributeError: 'ChatDeepSeek' object has no attribute 'call_as_llm'
